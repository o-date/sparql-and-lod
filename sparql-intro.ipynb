# %%
%lsmagics
# Out:
# Available magics:
# %auth  %display  %endpoint  %format  %graph  %lang  %log  %lsmagics  %outfile  %prefix  %qparam  %show
#
# %auth (basic|digest|none) <username> <passwd> : send HTTP authentication
# %display raw | table [withtypes] | diagram [svg|png] [withliterals] : set display format
# %endpoint <url> : set SPARQL endpoint. **REQUIRED**
# %format JSON | N3 | XML | any | default : set requested result format
# %graph <uri> : set default graph for the queries
# %lang <lang> [...] | default | all : language(s) preferred for labels
# %log critical | error | warning | info | debug : set logging level
# %lsmagics  : list all magics
# %outfile <filename> | NONE : save raw output to a file (use "%d" in name to add cell number, "NONE" to cancel saving)
# %prefix <name> [<uri>] : set (or delete) a persistent URI prefix for all queries
# %qparam <name> [<value>] : add (or delete) a persistent custom parameter to the endpoint query
# %show <n> | all : maximum number of shown results

# %%
%endpoint http://collection.britishmuseum.org/sparql
# Out:
# Endpoint set to: http://collection.britishmuseum.org/sparql

# %%
SELECT ?p ?o
WHERE {
  <http://collection.britishmuseum.org/id/object/PPA82633> ?p ?o .
}
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>p</th>
# <th>o</th></tr><tr class=odd><td class=val><a href="http://www.researchspace.org/ontology/PX_has_main_representation" target="_other">http://www.researchspace.org/ontology/PX_has_main_representation</a></td>
# <td class=val><a href="https://images.researchspace.org/collectionimages/AN00954/AN00954021_001_l.jpg" target="_other">https://images.researchspace.org/collectionimages/AN00954/AN00954021_001_l.jpg</a></td></tr><tr class=even><td class=val><a href="http://www.researchspace.org/ontology/Thing_created_on_Time" target="_other">http://www.researchspace.org/ontology/Thing_created_on_Time</a></td>
# <td class=val><a href="http://collection.britishmuseum.org/id/object/PPA82633/production/1/date" target="_other">http://collection.britishmuseum.org/id/object/PPA82633/production/1/date</a></td></tr><tr class=odd><td class=val><a href="http://www.researchspace.org/ontology/Thing_has_material_type_Concept" target="_other">http://www.researchspace.org/ontology/Thing_has_material_type_Concept</a></td>
# <td class=val><a href="http://collection.britishmuseum.org/id/thesauri/x11409" target="_other">http://collection.britishmuseum.org/id/thesauri/x11409</a></td></tr><tr class=even><td class=val><a href="http://www.researchspace.org/ontology/Thing_has_material_type_Concept" target="_other">http://www.researchspace.org/ontology/Thing_has_material_type_Concept</a></td>
# <td class=val><a href="http://collection.britishmuseum.org/id/thesauri/x11523" target="_other">http://collection.britishmuseum.org/id/thesauri/x11523</a></td></tr><tr class=odd><td class=val><a href="http://www.researchspace.org/ontology/Thing_has_technique_type_Concept" target="_other">http://www.researchspace.org/ontology/Thing_has_technique_type_Concept</a></td>
# <td class=val><a href="http://collection.britishmuseum.org/id/thesauri/x12291" target="_other">http://collection.britishmuseum.org/id/thesauri/x12291</a></td></tr><tr class=even><td class=val><a href="http://www.researchspace.org/ontology/Thing_has_technique_type_Concept" target="_other">http://www.researchspace.org/ontology/Thing_has_technique_type_Concept</a></td>
# <td class=val><a href="http://collection.britishmuseum.org/id/thesauri/x12126" target="_other">http://collection.britishmuseum.org/id/thesauri/x12126</a></td></tr><tr class=odd><td class=val><a href="http://www.researchspace.org/ontology/Thing_has_technique_type_Concept" target="_other">http://www.researchspace.org/ontology/Thing_has_technique_type_Concept</a></td>
# <td class=val><a href="http://collection.britishmuseum.org/id/thesauri/x12179" target="_other">http://collection.britishmuseum.org/id/thesauri/x12179</a></td></tr><tr class=even><td class=val><a href="http://www.researchspace.org/ontology/Thing_instance_of_Class" target="_other">http://www.researchspace.org/ontology/Thing_instance_of_Class</a></td>
# <td class=val><a href="http://www.cidoc-crm.org/cidoc-crm/E1_CRM_Entity" target="_other">http://www.cidoc-crm.org/cidoc-crm/E1_CRM_Entity</a></td></tr><tr class=odd><td class=val><a href="http://www.researchspace.org/ontology/Thing_instance_of_Class" target="_other">http://www.researchspace.org/ontology/Thing_instance_of_Class</a></td>
# <td class=val><a href="http://www.cidoc-crm.org/cidoc-crm/E18_Physical_Thing" target="_other">http://www.cidoc-crm.org/cidoc-crm/E18_Physical_Thing</a></td></tr><tr class=even><td class=val><a href="http://www.researchspace.org/ontology/Thing_instance_of_Class" target="_other">http://www.researchspace.org/ontology/Thing_instance_of_Class</a></td>
# <td class=val><a href="http://www.cidoc-crm.org/cidoc-crm/E19_Physical_Object" target="_other">http://www.cidoc-crm.org/cidoc-crm/E19_Physical_Object</a></td></tr><tr class=odd><td class=val><a href="http://www.researchspace.org/ontology/Thing_instance_of_Class" target="_other">http://www.researchspace.org/ontology/Thing_instance_of_Class</a></td>
# <td class=val><a href="http://www.cidoc-crm.org/cidoc-crm/E24_Physical_Man-Made_Thing" target="_other">http://www.cidoc-crm.org/cidoc-crm/E24_Physical_Man-Made_Thing</a></td></tr><tr class=even><td class=val><a href="http://www.researchspace.org/ontology/Thing_instance_of_Class" target="_other">http://www.researchspace.org/ontology/Thing_instance_of_Class</a></td>
# <td class=val><a href="http://www.cidoc-crm.org/cidoc-crm/E70_Thing" target="_other">http://www.cidoc-crm.org/cidoc-crm/E70_Thing</a></td></tr><tr class=odd><td class=val><a href="http://www.researchspace.org/ontology/Thing_instance_of_Class" target="_other">http://www.researchspace.org/ontology/Thing_instance_of_Class</a></td>
# <td class=val><a href="http://www.cidoc-crm.org/cidoc-crm/E71_Man-Made_Thing" target="_other">http://www.cidoc-crm.org/cidoc-crm/E71_Man-Made_Thing</a></td></tr><tr class=even><td class=val><a href="http://www.researchspace.org/ontology/Thing_instance_of_Class" target="_other">http://www.researchspace.org/ontology/Thing_instance_of_Class</a></td>
# <td class=val><a href="http://www.cidoc-crm.org/cidoc-crm/E72_Legal_Object" target="_other">http://www.cidoc-crm.org/cidoc-crm/E72_Legal_Object</a></td></tr><tr class=odd><td class=val><a href="http://www.researchspace.org/ontology/Thing_instance_of_Class" target="_other">http://www.researchspace.org/ontology/Thing_instance_of_Class</a></td>
# <td class=val><a href="http://www.cidoc-crm.org/cidoc-crm/E77_Persistent_Item" target="_other">http://www.cidoc-crm.org/cidoc-crm/E77_Persistent_Item</a></td></tr><tr class=even><td class=val><a href="http://www.researchspace.org/ontology/Thing_instance_of_Class" target="_other">http://www.researchspace.org/ontology/Thing_instance_of_Class</a></td>
# <td class=val><a href="http://www.cidoc-crm.org/cidoc-crm/E22_Man-Made_Object" target="_other">http://www.cidoc-crm.org/cidoc-crm/E22_Man-Made_Object</a></td></tr><tr class=odd><td class=val><a href="http://www.researchspace.org/ontology/Thing_refers_to_Thing" target="_other">http://www.researchspace.org/ontology/Thing_refers_to_Thing</a></td>
# <td class=val><a href="http://collection.britishmuseum.org/id/object/PPA82633/concept/1" target="_other">http://collection.britishmuseum.org/id/object/PPA82633/concept/1</a></td></tr><tr class=even><td class=val><a href="http://www.researchspace.org/ontology/Thing_refers_to_Thing" target="_other">http://www.researchspace.org/ontology/Thing_refers_to_Thing</a></td>
# <td class=val><a href="http://collection.britishmuseum.org/id/object/PPA82633/image/1" target="_other">http://collection.britishmuseum.org/id/object/PPA82633/image/1</a></td></tr><tr class=odd><td class=val><a href="http://www.researchspace.org/ontology/Thing_refers_to_Thing" target="_other">http://www.researchspace.org/ontology/Thing_refers_to_Thing</a></td>
# <td class=val><a href="http://collection.britishmuseum.org/id/object/PPA82633/inscription/1" target="_other">http://collection.britishmuseum.org/id/object/PPA82633/inscription/1</a></td></tr><tr class=even><td class=val><a href="http://www.w3.org/1999/02/22-rdf-syntax-ns#type" target="_other">http://www.w3.org/1999/02/22-rdf-syntax-ns#type</a></td>
# <td class=val><a href="http://www.researchspace.org/ontology/Thing" target="_other">http://www.researchspace.org/ontology/Thing</a></td></tr></table><div class="tinfo">Total: 100, Shown: 20</div></div>

# %%
%endpoint http://dbpedia.org/sparql
%display diagram

CONSTRUCT {
    ?p1 dbp:successor ?p2 .
    ?p2 dbp:successor ?p3 .
    ?p3 dbp:successor ?p4 .
}
WHERE {
    ?p1 rdf:type foaf:Person .
    ?p1 dbp:successor ?p2 .
    ?p2 dbp:successor ?p3 .
    ?p3 dbp:successor ?p4 .
}
LIMIT 50
# Out:
# Endpoint set to: http://dbpedia.org/sparql
# Display: svg
